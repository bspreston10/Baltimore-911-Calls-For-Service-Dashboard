# %%
# import packages
import pandas as pd 
import numpy as np

# %% [markdown]
# # Calls for service 2024

# %%
data_2024 = pd.read_csv('911_Calls_For_Services_2024.csv')

# %%
data_2024.head()
# Out:
#             callKey            callDateTime       priority district  \
# 0  10CC9DA965929F12  2024/01/01 06:16:00+00  Non-Emergency       SE
# 1  10CC9DA96592A321  2024/01/01 06:33:00+00  Non-Emergency       ND
# 2  10CC9DA96592B7B9  2024/01/01 08:01:00+00  Non-Emergency       CD
# 3  10CC9DA96592BCBA  2024/01/01 08:23:00+00  Non-Emergency       CD
# 4  10CC9DA96592DFE2  2024/01/01 10:53:00+00            Low       SD
#
#         description  callNumber  incidentLocation  \
# 0   NOISE COMPLAINT  P240011042   3600 PULASKI HY
# 1       Private Tow  P240011065   5000 DENMORE AV
# 2    PRKG COMPLAINT  P240011183    1400 ANCHOR ST
# 3    PRKG COMPLAINT  P240011224   1900 EASTERN AV
# 4  CHECK WELL-BEING  P240011605  1600 MARSHALL ST
#
#                         location          Neighborhood PoliceDistrict  ...  \
# 0   3600 PULASKI HY BALTIMORE MD   Baltimore Highlands   Southeastern  ...
# 1   5000 DENMORE AV BALTIMORE MD  Central Park Heights   Northwestern  ...
# ...

# %%
data_2024.columns
# Out:
# Index(['callKey', 'callDateTime', 'priority', 'district', 'description',
#        'callNumber', 'incidentLocation', 'location', 'Neighborhood',
#        'PoliceDistrict', 'PolicePost', 'CouncilDistrict', 'SheriffDistricts',
#        'Community_Statistical_Areas', 'Census_Tracts', 'VRIZones', 'ZIPCode',
#        'NeedsSync', 'IsDeleted', 'HashedRecord', 'ESRI_OID'],
#       dtype='object')

# %% [markdown]
# ## Dropping columns

# %%
data_2024 = data_2024.drop(columns=['incidentLocation', 'PolicePost', 'CouncilDistrict', 'SheriffDistricts', 'Community_Statistical_Areas', 
                        'Census_Tracts', 'VRIZones', 'NeedsSync', 'IsDeleted', 'HashedRecord', 'ESRI_OID'])

# %% [markdown]
# ## Fixing data types

# %%
data_2024.dtypes
# Out:
# callKey                        object
# callDateTime      datetime64[ns, UTC]
# priority                       object
# district                       object
# description                    object
# callNumber                     object
# location                       object
# Neighborhood                   object
# PoliceDistrict                 object
# ZIPCode                        object
# dtype: object

# %% [markdown]
# - callDateTime to datetime
# - ZIPCode to string

# %%
data_2024['callDateTime'] = pd.to_datetime(data_2024['callDateTime'])

# %%
data_2024['ZIPCode'] = data_2024['ZIPCode'].astype(str)

# %%
data_2024.head()
# Out:
#             callKey              callDateTime       priority district  \
# 0  10CC9DA965929F12 2024-01-01 06:16:00+00:00  Non-Emergency       SE
# 1  10CC9DA96592A321 2024-01-01 06:33:00+00:00  Non-Emergency       ND
# 2  10CC9DA96592B7B9 2024-01-01 08:01:00+00:00  Non-Emergency       CD
# 3  10CC9DA96592BCBA 2024-01-01 08:23:00+00:00  Non-Emergency       CD
# 4  10CC9DA96592DFE2 2024-01-01 10:53:00+00:00            Low       SD
#
#         description  callNumber                       location  \
# 0   NOISE COMPLAINT  P240011042   3600 PULASKI HY BALTIMORE MD
# 1       Private Tow  P240011065   5000 DENMORE AV BALTIMORE MD
# 2    PRKG COMPLAINT  P240011183    1400 ANCHOR ST BALTIMORE MD
# 3    PRKG COMPLAINT  P240011224   1900 EASTERN AV BALTIMORE MD
# 4  CHECK WELL-BEING  P240011605  1600 MARSHALL ST BALTIMORE MD
#
#            Neighborhood PoliceDistrict  ZIPCode
# 0   Baltimore Highlands   Southeastern  21224.0
# 1  Central Park Heights   Northwestern  21215.0
# ...

# %%
data_2024.to_csv('bmore_police_2024.csv')

# %% [markdown]
# # Calls for service 2023

# %%
data_2023 = pd.read_csv('911_Calls_For_Service_2023.csv')

# %%
data_2023.head()
# Out:
#             callKey              callDateTime       priority district  \
# 0  10CC9DA963B4126E 2023-01-03 06:33:00+00:00  Non-Emergency       NW
# 1  10CC9DA963B41D9B 2023-01-03 07:20:00+00:00            Low       SD
# 2  10CC9DA963B42534 2023-01-03 07:53:00+00:00            Low       NW
# 3  10CC9DA963B44289 2023-01-03 09:58:00+00:00  Non-Emergency       SW
# 4  10CC9DA963B44C0C 2023-01-03 10:38:00+00:00            Low       NW
#
#         description  callNumber                                      location  \
# 0  INVESTIGATE AUTO  P230031124  W BELVEDERE AV and PEMBRIDGE AV BALTIMORE MD
# 1           LARCENY  P230031180               1700 E PATAPSCO AV BALTIMORE MD
# 2       HIT AND RUN  P230031282             6900 REISTERSTOWN RD BALTIMORE MD
# 3       Private Tow  P230031792               2500 WASHINGTON BL BALTIMORE MD
# 4       HIT AND RUN  P230031938                3200 LABYRINTH RD BALTIMORE MD
#
#              Neighborhood PoliceDistrict  ZIPCode
# ...

# %%
data_2023 = data_2023.drop(columns=['incidentLocation', 'PolicePost', 'CouncilDistrict', 'SheriffDistricts', 'Community_Statistical_Areas', 
                        'Census_Tracts', 'VRIZones', 'NeedsSync', 'IsDeleted', 'HashedRecord', 'ESRI_OID'])

# %%
data_2023['callDateTime'] = pd.to_datetime(data_2023['callDateTime'])

# %%
data_2023['ZIPCode'] = data_2023['ZIPCode'].astype(str)

# %%
data_2023.to_csv('bmore_police_2023.csv')

# %% [markdown]
# # Calls for service 2022

# %%
data_2022 = pd.read_csv('911_Calls_for_Service_2022.csv')

# %%
data_2022.head()
# Out:
#    recordId           callKey            callDateTime       priority district  \
# 0  10079347  28CC9DA961CFE501  2022/01/01 05:22:00+00         Medium       SW
# 1  10079353  5301020A61CFE641  2022/01/01 05:27:00+00            Low       SW
# 2  10079356  5301020A61CFE017  2022/01/01 05:01:00+00         Medium       CD
# 3  10079367  5301020A61CFE20D  2022/01/01 05:09:00+00           High       SW
# 4  10079375  21CC9DA961CFE53E  2022/01/01 05:23:00+00  Non-Emergency       ND
#
#         description  callNumber            incidentLocation  \
# 0        DISORDERLY  P220010101       4400 BLK FREDERICK AV
# 1     AUTO ACCIDENT  P220010126  W BALTIMORE ST/N HILTON ST
# 2    COMMON ASSAULT  P220010014                1900 PARK AV
# 3   DISCHRG FIREARM  P220010044          500 BLK DENISON ST
# 4  INVESTIGATE AUTO  P220010108       NURTON AV/RUSCOMBE LN
#
#                                       location             Neighborhood  \
# ...

# %%
data_2022 = data_2022.drop(columns=['incidentLocation', 'PolicePost', 'CouncilDistrict', 'SheriffDistricts', 'Community_Statistical_Areas', 
                        'Census_Tracts', 'VRIZones', 'recordId'])

# %%
data_2022.head()
# Out:
#             callKey            callDateTime       priority district  \
# 0  28CC9DA961CFE501  2022/01/01 05:22:00+00         Medium       SW
# 1  5301020A61CFE641  2022/01/01 05:27:00+00            Low       SW
# 2  5301020A61CFE017  2022/01/01 05:01:00+00         Medium       CD
# 3  5301020A61CFE20D  2022/01/01 05:09:00+00           High       SW
# 4  21CC9DA961CFE53E  2022/01/01 05:23:00+00  Non-Emergency       ND
#
#         description  callNumber                                     location  \
# 0        DISORDERLY  P220010101           4400 BLK FREDERICK AV BALTIMORE MD
# 1     AUTO ACCIDENT  P220010126  W BALTIMORE ST and N HILTON ST BALTIMORE MD
# 2    COMMON ASSAULT  P220010014                    1900 PARK AV BALTIMORE MD
# 3   DISCHRG FIREARM  P220010044              500 BLK DENISON ST BALTIMORE MD
# 4  INVESTIGATE AUTO  P220010108       NURTON AV and RUSCOMBE LN BALTIMORE MD
#
#               Neighborhood PoliceDistrict  ZIPCode
# ...

# %%
data_2022['callDateTime'] = pd.to_datetime(data_2022['callDateTime'])

# %%
data_2022['ZIPCode'] = data_2022['ZIPCode'].astype(str)

# %%
print(data_2022.dtypes)
data_2022.head()
# Out:
# callKey                        object
# callDateTime      datetime64[ns, UTC]
# priority                       object
# district                       object
# description                    object
# callNumber                     object
# location                       object
# Neighborhood                   object
# PoliceDistrict                 object
# ZIPCode                        object
# dtype: object
#             callKey              callDateTime       priority district  \
# 0  28CC9DA961CFE501 2022-01-01 05:22:00+00:00         Medium       SW
# 1  5301020A61CFE641 2022-01-01 05:27:00+00:00            Low       SW
# 2  5301020A61CFE017 2022-01-01 05:01:00+00:00         Medium       CD
# 3  5301020A61CFE20D 2022-01-01 05:09:00+00:00           High       SW
# 4  21CC9DA961CFE53E 2022-01-01 05:23:00+00:00  Non-Emergency       ND
#
#         description  callNumber                                     location  \
# ...

# %%
data_2022.to_csv('bmore_police_2022.csv')

# %% [markdown]
# # Calls for service 2021

# %%
data_2021 = pd.read_csv('911_Calls_for_Service_2021.csv')

# %%
data_2021.head()
# Out:
#    recordId           callKey            callDateTime priority district  \
# 0   8702319  13CC9DA95FEEB67E  2021/01/01 05:43:00+00      Low       NE
# 1   8702320  1ACC9DA95FEEADAE  2021/01/01 05:05:00+00     High       WD
# 2   8702321  29CC9DA95FEEAF64  2021/01/01 05:13:00+00   Medium       ND
# 3   8702323  5401020A5FEEAD52  2021/01/01 05:04:00+00   Medium       WD
# 4   8702325  5401020A5FEEB0D1  2021/01/01 05:19:00+00   Medium       SE
#
#        description  callNumber      incidentLocation  \
# 0    AUTO ACCIDENT  P210010214        1500 E 29TH ST
# 1  DISCHRG FIREARM  P210010052       300 N GILMOR ST
# 2       DISORDERLY  P210010098   E 0TH ST/ST PAUL ST
# 3   WANTED ON WARR  P210010036  1700 GWYNNS FALLS PY
# 4   FAMILY DISTURB  P210010120       600 RAPPOLLA ST
#
#                                location                     Neighborhood  \
# 0           1500 E 29TH ST BALTIMORE MD  Coldstream Homestead Montebello
# ...

# %%
data_2021 = data_2021.drop(columns=['incidentLocation', 'PolicePost', 'CouncilDistrict', 'SheriffDistricts', 'Community_Statistical_Areas', 
                        'Census_Tracts', 'VRIZones', 'recordId'])

# %%
data_2021['callDateTime'] = pd.to_datetime(data_2021['callDateTime'])

# %%
data_2021['ZIPCode'] = data_2021['ZIPCode'].astype(str)

# %%
print(data_2021.dtypes)
data_2021.head()
# Out:
# callKey                        object
# callDateTime      datetime64[ns, UTC]
# priority                       object
# district                       object
# description                    object
# callNumber                     object
# location                       object
# Neighborhood                   object
# PoliceDistrict                 object
# ZIPCode                        object
# dtype: object
#             callKey              callDateTime priority district  \
# 0  13CC9DA95FEEB67E 2021-01-01 05:43:00+00:00      Low       NE
# 1  1ACC9DA95FEEADAE 2021-01-01 05:05:00+00:00     High       WD
# 2  29CC9DA95FEEAF64 2021-01-01 05:13:00+00:00   Medium       ND
# 3  5401020A5FEEAD52 2021-01-01 05:04:00+00:00   Medium       WD
# 4  5401020A5FEEB0D1 2021-01-01 05:19:00+00:00   Medium       SE
#
#        description  callNumber                              location  \
# 0    AUTO ACCIDENT  P210010214           1500 E 29TH ST BALTIMORE MD
# ...

# %%
data_2021.to_csv('bmore_police_2021.csv')

# %% [markdown]
# # Calls for service 2020

# %%
data_2020 = pd.read_csv('911_Calls_for_Service_2020.csv')

# %%
data_2020.head()
# Out:
#    recordId           callKey            callDateTime priority district  \
# 0   7033251  5701020A5E0C29FB  2020/01/01 05:11:00+00   Medium       NE
# 1   7033252  5901020A5E0C2866  2020/01/01 05:04:00+00   Medium       ND
# 2   7033253  5901020A5E0C2809  2020/01/01 05:03:00+00   Medium       NE
# 3   7033254  5901020A5E0C2A0A  2020/01/01 05:11:00+00     High       NE
# 4   7033255  5901020A5E0C28BC  2020/01/01 05:06:00+00      Low       CD
#
#        description  callNumber      incidentLocation  \
# 0       DISORDERLY  P200010061  KEENE AV/BIDDISON AV
# 1       DISORDERLY  P200010029         800 W 40TH ST
# 2   FAMILY DISTURB  P200010021      1600 PENTWOOD RD
# 3  DISCHRG FIREARM  P200010065       6800 MCCLEAN BL
# 4            OTHER  P200010043      600 E FAYETTE ST
#
#                                 location                Neighborhood  \
# 0  KEENE AV and BIDDISON AV BALTIMORE MD              Glenham-Belhar
# 1             800 W 40TH ST BALTIMORE MD                 Roland Park
# ...

# %%
data_2020 = data_2020.drop(columns=['incidentLocation', 'PolicePost', 'CouncilDistrict', 'SheriffDistricts', 'Community_Statistical_Areas', 
                        'Census_Tracts', 'VRIZones', 'recordId'])

# %%
data_2020['callDateTime'] = pd.to_datetime(data_2020['callDateTime'])

# %%
data_2020['ZIPCode'] = data_2020['ZIPCode'].astype(str)

# %%
print(data_2020.dtypes)
data_2020.head()
# Out:
# callKey                        object
# callDateTime      datetime64[ns, UTC]
# priority                       object
# district                       object
# description                    object
# callNumber                     object
# location                       object
# Neighborhood                   object
# PoliceDistrict                 object
# ZIPCode                        object
# dtype: object
#             callKey              callDateTime priority district  \
# 0  5701020A5E0C29FB 2020-01-01 05:11:00+00:00   Medium       NE
# 1  5901020A5E0C2866 2020-01-01 05:04:00+00:00   Medium       ND
# 2  5901020A5E0C2809 2020-01-01 05:03:00+00:00   Medium       NE
# 3  5901020A5E0C2A0A 2020-01-01 05:11:00+00:00     High       NE
# 4  5901020A5E0C28BC 2020-01-01 05:06:00+00:00      Low       CD
#
#        description  callNumber                               location  \
# 0       DISORDERLY  P200010061  KEENE AV and BIDDISON AV BALTIMORE MD
# ...

# %%
data_2020.to_csv('bmore_police_2020.csv')

# %% [markdown]
# # Calls for service 2019

# %%
data_2019 = pd.read_csv('911_Calls_for_Service_2019.csv')

# %%
data_2019.head()
# Out:
#    recordId           callKey            callDateTime       priority district  \
# 0         1  9C01020A5C701086  2019/02/22 15:08:00+00  Non-Emergency       WD
# 1         2  9C01020A5C701088  2019/02/22 15:08:00+00  Non-Emergency       WD
# 2         3  9C01020A5C701038  2019/02/22 15:07:00+00  Non-Emergency       SE
# 3         4  9C01020A5C701031  2019/02/22 15:07:00+00  Non-Emergency       ND
# 4         5  5401020A5C701048  2019/02/22 15:07:00+00            Low       NE
#
#       description  callNumber           incidentLocation  \
# 0  Hot Spot Check  P190531374  W BALTIMORE ST/N BRUCE ST
# 1  Hot Spot Check  P190531375    1600 BLK N SMALLWOOD ST
# 2           Other  P190531365              200 N ROSE ST
# 3  Hot Spot Check  P190531364               4600 YORK RD
# 4   911/NO  VOICE  P190531371            5900 RADECKE AV
#
#                                      location                Neighborhood  \
# 0  W BALTIMORE ST and N BRUCE ST BALTIMORE MD             Franklin Square
# ...

# %%
data_2019 = data_2019.drop(columns=['incidentLocation', 'PolicePost', 'CouncilDistrict', 'SheriffDistricts', 'Community_Statistical_Areas', 
                        'Census_Tracts', 'VRIZones', 'recordId'])

# %%
data_2019['callDateTime'] = pd.to_datetime(data_2019['callDateTime'])

# %%
data_2019['ZIPCode'] = data_2019['ZIPCode'].astype(str)

# %%
print(data_2019.dtypes)
data_2019.head()
# Out:
# callKey                        object
# callDateTime      datetime64[ns, UTC]
# priority                       object
# district                       object
# description                    object
# callNumber                     object
# location                       object
# Neighborhood                   object
# PoliceDistrict                 object
# ZIPCode                        object
# dtype: object
#             callKey              callDateTime       priority district  \
# 0  9C01020A5C701086 2019-02-22 15:08:00+00:00  Non-Emergency       WD
# 1  9C01020A5C701088 2019-02-22 15:08:00+00:00  Non-Emergency       WD
# 2  9C01020A5C701038 2019-02-22 15:07:00+00:00  Non-Emergency       SE
# 3  9C01020A5C701031 2019-02-22 15:07:00+00:00  Non-Emergency       ND
# 4  5401020A5C701048 2019-02-22 15:07:00+00:00            Low       NE
#
#       description  callNumber                                    location  \
# ...

# %%
data_2019.to_csv('bmore_police_2019.csv')

# %% [markdown]
# # Calls for service 2018

# %%
data_2018 = pd.read_csv('911_Calls_for_Service_2018.csv')

# %%
data_2018.head()
# Out:
#    recordId           callKey            callDateTime       priority district  \
# 0    174931  9C01020A5C2AF3B1  2019/01/01 04:59:00+00  Non-Emergency       WD
# 1    174932  9C01020A5C2AF37C  2019/01/01 04:58:00+00  Non-Emergency       WD
# 2    174933  5F01020A5C2AF35E  2019/01/01 04:58:00+00         Medium       CD
# 3    174934  9C01020A5C2AF325  2019/01/01 04:57:00+00  Non-Emergency       ED
# 4    174935  5E01020A5C2AF33D  2019/01/01 04:57:00+00         Medium       ED
#
#       description  callNumber     incidentLocation  \
# 0  Hot Spot Check  P183653281  2300 W BALTIMORE ST
# 1  Hot Spot Check  P183653279  2300 W BALTIMORE ST
# 2   911/NO  VOICE  P183653283     600 E FAYETTE ST
# 3  Business Check  P183653278       1900 BELAIR RD
# 4  FAMILY DISTURB  P183653282       1100 ABBOTT CT
#
#                            location                     Neighborhood  \
# 0  2300 W BALTIMORE ST BALTIMORE MD                     Shipley Hill
# ...

# %%
data_2018 = data_2018.drop(columns=['incidentLocation', 'PolicePost', 'CouncilDistrict', 'SheriffDistricts', 'Community_Statistical_Areas', 
                        'Census_Tracts', 'VRIZones', 'recordId'])

# %%
data_2018['callDateTime'] = pd.to_datetime(data_2018['callDateTime'])

# %%
data_2018['ZIPCode'] = data_2018['ZIPCode'].astype(str)

# %%
print(data_2018.dtypes)
data_2018.head()
# Out:
# callKey                        object
# callDateTime      datetime64[ns, UTC]
# priority                       object
# district                       object
# description                    object
# callNumber                     object
# location                       object
# Neighborhood                   object
# PoliceDistrict                 object
# ZIPCode                        object
# dtype: object
#             callKey              callDateTime       priority district  \
# 0  9C01020A5C2AF3B1 2019-01-01 04:59:00+00:00  Non-Emergency       WD
# 1  9C01020A5C2AF37C 2019-01-01 04:58:00+00:00  Non-Emergency       WD
# 2  5F01020A5C2AF35E 2019-01-01 04:58:00+00:00         Medium       CD
# 3  9C01020A5C2AF325 2019-01-01 04:57:00+00:00  Non-Emergency       ED
# 4  5E01020A5C2AF33D 2019-01-01 04:57:00+00:00         Medium       ED
#
#       description  callNumber                          location  \
# 0  Hot Spot Check  P183653281  2300 W BALTIMORE ST BALTIMORE MD
# ...

# %%
data_2018.to_csv('bmore_police_2018.csv')

# %% [markdown]
# # Calls for Service 2017

# %%
data_2017 = pd.read_csv('911_Calls_for_Service_2017.csv')

# %%
data_2017.head()
# Out:
#    recordId           callKey            callDateTime       priority district  \
# 0   1172010  6101020A5A49C037  2018/01/01 04:59:00+00         Medium       SE
# 1   1172011  5A01020A5A49C032  2018/01/01 04:59:00+00         Medium       ND
# 2   1172012  9C01020A5A49C006  2018/01/01 04:58:00+00  Non-Emergency       NE
# 3   1172013  6401020A5A49BFD9  2018/01/01 04:58:00+00         Medium       NE
# 4   1172014  5501020A5A49BFE7  2018/01/01 04:58:00+00            Low       CD
#
#       description  callNumber   incidentLocation  \
# 0   911/NO  VOICE  P173652251     500 S BROADWAY
# 1      DISORDERLY  P180010002  2100 N CHARLES ST
# 2  Business Check  P173652247    6000 HARFORD RD
# 3  FAMILY DISTURB  P173652248     3600 BELAIR RD
# 4           OTHER  P180010005  FALLSWAY/N GAY ST
#
#                              location   Neighborhood PoliceDistrict  \
# 0         500 S BROADWAY BALTIMORE MD    Fells Point   Southeastern
# ...

# %%
data_2017 = data_2017.drop(columns=['incidentLocation', 'PolicePost', 'CouncilDistrict', 'SheriffDistricts', 'Community_Statistical_Areas', 
                        'Census_Tracts', 'VRIZones', 'recordId'])

# %%
data_2017['callDateTime'] = pd.to_datetime(data_2017['callDateTime'])

# %%
data_2017['ZIPCode'] = data_2017['ZIPCode'].astype(str)

# %%
print(data_2017.dtypes)
data_2017.head()
# Out:
# callKey                        object
# callDateTime      datetime64[ns, UTC]
# priority                       object
# district                       object
# description                    object
# callNumber                     object
# location                       object
# Neighborhood                   object
# PoliceDistrict                 object
# ZIPCode                        object
# dtype: object
#             callKey              callDateTime       priority district  \
# 0  6101020A5A49C037 2018-01-01 04:59:00+00:00         Medium       SE
# 1  5A01020A5A49C032 2018-01-01 04:59:00+00:00         Medium       ND
# 2  9C01020A5A49C006 2018-01-01 04:58:00+00:00  Non-Emergency       NE
# 3  6401020A5A49BFD9 2018-01-01 04:58:00+00:00         Medium       NE
# 4  5501020A5A49BFE7 2018-01-01 04:58:00+00:00            Low       CD
#
#       description  callNumber                            location  \
# 0   911/NO  VOICE  P173652251         500 S BROADWAY BALTIMORE MD
# ...

# %%
data_2017.to_csv('bmore_police_2017.csv')

# %% [markdown]
# # Calls for service 2016

# %%
data_2016 = pd.read_csv('911_Calls_for_Service_2016.csv')

# %%
data_2016.head()
# Out:
#    recordId           callKey            callDateTime       priority district  \
# 0   2178302  5E01020A58688C7F  2017/01/01 04:58:00+00  Non-Emergency       NE
# 1   2178303  9C01020A58688C4A  2017/01/01 04:57:00+00  Non-Emergency       SD
# 2   2178304  9C01020A58688C53  2017/01/01 04:57:00+00  Non-Emergency       SE
# 3   2178305  6201020A58688C3F  2017/01/01 04:57:00+00         Medium       SE
# 4   2178306  9C01020A58688BE9  2017/01/01 04:56:00+00  Non-Emergency       SD
#
#         description  callNumber         incidentLocation  \
# 0  INVESTIGATE AUTO  P163662662       3600 BLK KIMBLE RD
# 1             Other  P163662658  SOUTHERN DISTRICT #ACRS
# 2     TOWED VEHICLE  P163662659              0 S HIGH ST
# 3          BURGLARY  P163662660        3200 E LOMBARD ST
# 4      Foot  Patrol  P163662652       HAUBERT ST/HULL ST
#
#                                location                  Neighborhood  \
# 0       3600 BLK KIMBLE RD BALTIMORE MD        Ednor Gardens-Lakeside
# ...

# %%
data_2016 = data_2016.drop(columns=['incidentLocation', 'PolicePost', 'CouncilDistrict', 'SheriffDistricts', 'Community_Statistical_Areas', 
                        'Census_Tracts', 'VRIZones', 'recordId'])

# %%
data_2016['callDateTime'] = pd.to_datetime(data_2016['callDateTime'])

# %%
data_2016['ZIPCode'] = data_2016['ZIPCode'].astype(str)

# %%
print(data_2016.dtypes)
data_2016.head()
# Out:
# callKey                        object
# callDateTime      datetime64[ns, UTC]
# priority                       object
# district                       object
# description                    object
# callNumber                     object
# location                       object
# Neighborhood                   object
# PoliceDistrict                 object
# ZIPCode                        object
# dtype: object
#             callKey              callDateTime       priority district  \
# 0  5E01020A58688C7F 2017-01-01 04:58:00+00:00  Non-Emergency       NE
# 1  9C01020A58688C4A 2017-01-01 04:57:00+00:00  Non-Emergency       SD
# 2  9C01020A58688C53 2017-01-01 04:57:00+00:00  Non-Emergency       SE
# 3  6201020A58688C3F 2017-01-01 04:57:00+00:00         Medium       SE
# 4  9C01020A58688BE9 2017-01-01 04:56:00+00:00  Non-Emergency       SD
#
#         description  callNumber                              location  \
# 0  INVESTIGATE AUTO  P163662662       3600 BLK KIMBLE RD BALTIMORE MD
# ...

# %%
data_2016.to_csv('bmore_police_2016.csv')

# %% [markdown]
# # Calls for service 2015

# %%
data_2015 = pd.read_csv('911_Calls_for_Service_2015.csv')
# Out:
# /var/folders/kq/dy0jdntd27z3gx741y_j5p880000gn/T/ipykernel_62737/508027008.py:1: DtypeWarning: Columns (1,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_2015 = pd.read_csv('911_Calls_for_Service_2015.csv')

# %%
data_2015.head()
# Out:
#    recordId           callKey            callDateTime priority district  \
# 0   3231243  5D01020A568607A8  2016/01/01 04:59:00+00   Medium       NE
# 1   3231244  6101020A568607A8  2016/01/01 04:59:00+00   Medium       SW
# 2   3231245  6F01020A568607BE  2016/01/01 04:59:00+00   Medium       ND
# 3   3231246  6001020A568607BA  2016/01/01 04:59:00+00   Medium       CD
# 4   3231247  6401020A568607BC  2016/01/01 04:59:00+00      Low       CD
#
#   description  callNumber       incidentLocation  \
# 0   UNFOUNDED  P153653180       3700 BLK MARY AV
# 1  DISORDERLY  P153653179   1000 POPLAR GROVE ST
# 2  DISORDERLY  P160010002          1200 UNION AV
# 3   UNFOUNDED  P160010008  W READ ST/N HOWARD ST
# 4       OTHER  P160010004           300 LIGHT ST
#
#                                  location    Neighborhood PoliceDistrict  \
# 0           3700 BLK MARY AV BALTIMORE MD  Glenham-Belhar   Northeastern
# 1       1000 POPLAR GROVE ST BALTIMORE MD          Mosher        Western
# ...

# %%
data_2015 = data_2015.drop(columns=['incidentLocation', 'PolicePost', 'CouncilDistrict', 'SheriffDistricts', 'Community_Statistical_Areas', 
                        'Census_Tracts', 'VRIZones', 'recordId'])

# %%
data_2015['callDateTime'] = pd.to_datetime(data_2015['callDateTime'])

# %%
data_2015['ZIPCode'] = data_2015['ZIPCode'].astype(str)

# %%
print(data_2015.dtypes)
data_2015.head()
# Out:
# callKey                        object
# callDateTime      datetime64[ns, UTC]
# priority                       object
# district                       object
# description                    object
# callNumber                     object
# location                       object
# Neighborhood                   object
# PoliceDistrict                 object
# ZIPCode                        object
# dtype: object
#             callKey              callDateTime priority district description  \
# 0  5D01020A568607A8 2016-01-01 04:59:00+00:00   Medium       NE   UNFOUNDED
# 1  6101020A568607A8 2016-01-01 04:59:00+00:00   Medium       SW  DISORDERLY
# 2  6F01020A568607BE 2016-01-01 04:59:00+00:00   Medium       ND  DISORDERLY
# 3  6001020A568607BA 2016-01-01 04:59:00+00:00   Medium       CD   UNFOUNDED
# 4  6401020A568607BC 2016-01-01 04:59:00+00:00      Low       CD       OTHER
#
#    callNumber                                location    Neighborhood  \
# ...

# %%
data_2015.to_csv('bmore_police_2015.csv')

# %% [markdown]
# # Calls for service 2014

# %%
data_2014 = pd.read_csv('911_Calls_for_Service_2014.csv')

# %%
data_2014.head()
# Out:
#    recordId    callKey            callDateTime priority district  \
# 0   4310736  707029823  2015/01/01 04:59:00+00   Medium       ND
# 1   4310737  707029826  2015/01/01 04:59:00+00   Medium       SW
# 2   4310738  707029827  2015/01/01 04:59:00+00   Medium       WD
# 3   4310739  707029824  2015/01/01 04:58:00+00      Low       ND
# 4   4310740  707029819  2015/01/01 04:58:00+00      Low       NE
#
#       description  callNumber      incidentLocation  \
# 0    911/No Voice   150010002        1600 W 41ST ST
# 1  Family Disturb   150010004        2500 TOLLEY ST
# 2        Burglary   150010005        900 BENNETT PL
# 3           Other   150010003   2500 W BELVEDERE AV
# 4    Traffic Stop   143652833  2200-BLK LONGVIEW AV
#
#                             location            Neighborhood PoliceDistrict  \
# 0        1600 W 41ST ST BALTIMORE MD                Medfield       Northern
# 1        2500 TOLLEY ST BALTIMORE MD            Morrell Park   Southwestern
# ...

# %%
data_2014 = data_2014.drop(columns=['incidentLocation', 'PolicePost', 'CouncilDistrict', 'SheriffDistricts', 'Community_Statistical_Areas', 
                        'Census_Tracts', 'VRIZones', 'recordId'])

# %%
data_2014['callDateTime'] = pd.to_datetime(data_2014['callDateTime'])

# %%
data_2014['ZIPCode'] = data_2014['ZIPCode'].astype(str)

# %%
print(data_2014.dtypes)
data_2014.head()
# Out:
# callKey                         int64
# callDateTime      datetime64[ns, UTC]
# priority                       object
# district                       object
# description                    object
# callNumber                      int64
# location                       object
# Neighborhood                   object
# PoliceDistrict                 object
# ZIPCode                        object
# dtype: object
#      callKey              callDateTime priority district     description  \
# 0  707029823 2015-01-01 04:59:00+00:00   Medium       ND    911/No Voice
# 1  707029826 2015-01-01 04:59:00+00:00   Medium       SW  Family Disturb
# 2  707029827 2015-01-01 04:59:00+00:00   Medium       WD        Burglary
# 3  707029824 2015-01-01 04:58:00+00:00      Low       ND           Other
# 4  707029819 2015-01-01 04:58:00+00:00      Low       NE    Traffic Stop
#
#    callNumber                           location            Neighborhood  \
# ...

# %%
data_2014.to_csv('bmore_police_2014.csv')
